# %% [markdown]
# ### 1、计算并生成linker的数量

# %%
# /home/dqrong/Dnacomputing-main/data/0-lib-linker/main.ipynb
# 1、计算并生成linker
# output：
#    linker.txt :所有linker
#    linker_val.txt:有效linker库
#    linker_inv.txt:无效linker库

# %% [markdown]
# ### 2、linker库信息统计
